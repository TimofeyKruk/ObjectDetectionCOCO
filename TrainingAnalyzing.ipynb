# %% [markdown]
# ### Object detection analysis

# %%
import data_preparation
import torchvision
import numpy as np
import matplotlib.pyplot as plt

def show_image(batch):
    images, labels = batch
    images=torchvision.utils.make_grid(images[:4])
    images=images/2+0.5
    npimages=images.numpy()
    
    plt.figure(figsize=(5,5))
    plt.imshow(np.transpose(npimages,(1,2,0)))
    plt.show()
    print(labels[0])
    #print(' '.join('%5s' % classes_names[labels[j]] for j in range(4)))

# %%
train,test=data_preparation.loadCOCO()
# Out:
# loading annotations into memory...
# Done (t=13.91s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.18s)
# creating index...
# index created!

# %%
it=iter(train)

im,lab=it.next()
print(im)
print("No break!")
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-4-f3c88478cfd2> in <module>
# ----> 1 it=iter(train)
#       2
#       3 im,lab=it.next()
#       4 print(im)
#       5 print("No break!")
#
# c:\python\lib\site-packages\torch\utils\data\dataloader.py in __iter__(self)
#     277             return _SingleProcessDataLoaderIter(self)
#     278         else:
# --> 279             return _MultiProcessingDataLoaderIter(self)
#     280
#     281     @property
#
# c:\python\lib\site-packages\torch\utils\data\dataloader.py in __init__(self, loader)
#     717             #     before it starts, and __del__ tries to join but will get:
#     718             #     AssertionError: can only join a started process.
# --> 719             w.start()
#     720             self._index_queues.append(index_queue)
#     721             self._workers.append(w)
#
# ...

# %%
train_l = data_preparation.loadCOCO(train_bool=True)
print("Loader starts!")

for batch in train_l:
    img,lab=batch
    imgn=img.numpy()
    imgn=np.transpose(imgn[0,:,:,:],(1,2,0))
    plt.imshow(imgn)
    print(lab["bbox"])
    break
# Out:
# loading annotations into memory...
# Done (t=77.19s)
# creating index...
# index created!
# Loader starts!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-cbb4db4228c2> in <module>
#       7     imgn=np.transpose(imgn[0,:,:,:],(1,2,0))
#       8     plt.imshow(imgn)
# ----> 9     print(lab["bbox"])
#      10     break
#
# TypeError: list indices must be integers or slices, not str

# %%
for key in lab[0].keys():
    print(key,lab[0][key])
# Out:
# segmentation [[tensor([214.7800], dtype=torch.float64), tensor([466.6700], dtype=torch.float64), tensor([196.], dtype=torch.float64), tensor([480.4400], dtype=torch.float64), tensor([175.9600], dtype=torch.float64), tensor([489.2100], dtype=torch.float64), tensor([157.8100], dtype=torch.float64), tensor([496.0900], dtype=torch.float64), tensor([136.5300], dtype=torch.float64), tensor([501.7300], dtype=torch.float64), tensor([124.6300], dtype=torch.float64), tensor([502.3500], dtype=torch.float64), tensor([110.8600], dtype=torch.float64), tensor([502.9800], dtype=torch.float64), tensor([84.5700], dtype=torch.float64), tensor([499.8500], dtype=torch.float64), tensor([72.0500], dtype=torch.float64), tensor([495.4700], dtype=torch.float64), tensor([68.2900], dtype=torch.float64), tensor([490.4600], dtype=torch.float64), tensor([65.1600], dtype=torch.float64), tensor([472.9300], dtype=torch.float64), tensor([80.8100], dtype=torch.float64), tensor([461.6600], dtype=torch.float64), tensor([
# ...
